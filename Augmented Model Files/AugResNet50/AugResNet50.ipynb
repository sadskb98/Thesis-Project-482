# %%
import numpy as np
import pandas as pd
import pickle
import numpy as np
import random
import time
import os
#os.environ["OPENCV_IO_MAX_IMAGE_PIXELS"] = pow(2,40).__str__()
import cv2
from tqdm import tqdm

import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from keras import optimizers
#from sklearn.metrics import classification_report, confusion_matrix
import sklearn
import seaborn as sn
from keras.callbacks import CSVLogger, LambdaCallback
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the dataset file in Google Drive
dataset_path_drive = '/content/drive/MyDrive/Project_482/Augmented_Dataset.zip'

# Path to the destination directory in Colab
dataset_path_colab = '/content/aug_dataset.zip'

# Copy the dataset file from Google Drive to Colab
# !cp "{dataset_path_drive}" "{dataset_path_colab}"

# %%
# !unzip /content/aug_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Augmented_Dataset/train/PD/2229a.jpg
#   inflating: Augmented_Dataset/train/PD/2268a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_814.png
#   inflating: Augmented_Dataset/train/PD/PD_16.png
#   inflating: Augmented_Dataset/train/PD/2335a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_445.png
#   inflating: Augmented_Dataset/train/PD/PD_873.png
#   inflating: Augmented_Dataset/train/PD/PD_708.png
#   inflating: Augmented_Dataset/train/PD/PD_270.png
#   inflating: Augmented_Dataset/train/PD/PD_834.png
#   inflating: Augmented_Dataset/train/PD/2397a.jpg
#   inflating: Augmented_Dataset/train/PD/1756a.jpg
#   inflating: Augmented_Dataset/train/PD/3129a.jpg
#   inflating: Augmented_Dataset/train/PD/2965a.jpg
#   inflating: Augmented_Dataset/train/PD/2842a.jpg
#   inflating: Augmented_Dataset/train/PD/1433a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_468.png
#   inflating: Augmented_Dataset/train/PD/1430a.jpg
#   inflating: Augmented_Dataset/train/PD/1918a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_323.png
#   inflating: Augmented_Dataset/train/PD/2784a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_257.png
#   inflating: Augmented_Dataset/train/PD/PD_72.png
#   inflating: Augmented_Dataset/train/PD/PD_464.png
#   inflating: Augmented_Dataset/train/PD/2399a.jpg
#   inflating: Augmented_Dataset/train/PD/2098a.jpg
#   inflating: Augmented_Dataset/train/PD/2448a.jpg
#   inflating: Augmented_Dataset/train/PD/1954a.jpg
#   inflating: Augmented_Dataset/train/PD/1340a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_510.png
#   inflating: Augmented_Dataset/train/PD/2188a.jpg
#   inflating: Augmented_Dataset/train/PD/1422a.jpg
#   inflating: Augmented_Dataset/train/PD/1677a.jpg
#   inflating: Augmented_Dataset/train/PD/3046a.jpg
#   inflating: Augmented_Dataset/train/PD/1627a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_75.png
#   inflating: Augmented_Dataset/train/PD/PD_605.png
#   inflating: Augmented_Dataset/train/PD/PD_216.png
#   inflating: Augmented_Dataset/train/PD/3017a.jpg
#   inflating: Augmented_Dataset/train/PD/1791a.jpg
#   inflating: Augmented_Dataset/train/PD/1441a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_112.png
#   inflating: Augmented_Dataset/train/PD/PD_609.png
#   inflating: Augmented_Dataset/train/PD/3067a.jpg
#   inflating: Augmented_Dataset/train/PD/3131a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_255.png
#   inflating: Augmented_Dataset/train/PD/1693a.jpg
#   inflating: Augmented_Dataset/train/PD/PD_875.png
#   inflating: Augmented_Dataset/train/PD/PD_139.png
#   inflating: Augmented_Dataset/train/PD/PD_325.png
#   inflating: Augmented_Dataset/train/PD/1527a.jpg
#   inflating: Augmented_Dataset/train/PD/PD
#   inflating: Augmented_Dataset/validation/PD/748a.jpg
#   inflating: Augmented_Dataset/validation/PD/482a.jpg
#   inflating: Augmented_Dataset/validation/PD/531a.jpg
#   inflating: Augmented_Dataset/validation/PD/815a.jpg
#   inflating: Augmented_Dataset/validation/PD/907a.jpg
#   inflating: Augmented_Dataset/validation/PD/566a.jpg
#   inflating: Augmented_Dataset/validation/PD/707a.jpg
#   inflating: Augmented_Dataset/validation/PD/677a.jpg
#   inflating: Augmented_Dataset/validation/PD/922a.jpg
#   inflating: Augmented_Dataset/validation/PD/860a.jpg
#   inflating: Augmented_Dataset/validation/PD/692a.jpg
#   inflating: Augmented_Dataset/validation/PD/997a.jpg
#   inflating: Augmented_Dataset/validation/PD/592a.jpg
#   inflating: Augmented_Dataset/validation/PD/669a.jpg
#   inflating: Augmented_Dataset/validation/PD/517a.jpg
#   inflating: Augmented_Dataset/validation/PD/820a.jpg
#   inflating: Augmented_Dataset/validation/PD/520a.jpg
#   inflating: Augmented_Dataset/validation/PD/711a.jpg
#   inflating: Augmented_Dataset/validation/PD/708a.jpg
#   inflating: Augmented_Dataset/validation/PD/475a.jpg
#   inflating: Augmented_Dataset/validation/PD/747a.jpg
#   inflating: Augmented_Dataset/validation/PD/918a.jpg
#   inflating: Augmented_Dataset/validation/PD/489a.jpg
#   inflating: Augmented_Dataset/validation/PD/653a.jpg
#   inflating: Augmented_Dataset/validation/PD/968a.jpg
#   inflating: Augmented_Dataset/validation/PD/491a.jpg
#   inflating: Augmented_Dataset/validation/PD/947a.jpg
#   inflating: Augmented_Dataset/validation/PD/553a.jpg
#   inflating: Augmented_Dataset/validation/PD/535a.jpg
#   inflating: Augmented_Dataset/validation/PD/574a.jpg
#   inflating: Augmented_Dataset/validation/PD/802a.jpg
#   inflating: Augmented_Dataset/validation/PD/516a.jpg
#   inflating: Augmented_Dataset/validation/PD/486a.jpg
#   inflating: Augmented_Dataset/validation/PD/479a.jpg
#   inflating: Augmented_Dataset/validation/PD/655a.jpg
#   inflating: Augmented_Dataset/validation/PD/877a.jpg
#   inflating: Augmented_Dataset/validation/PD/905a.jpg
#   inflating: Augmented_Dataset/validation/PD/864a.jpg
#   inflating: Augmented_Dataset/validation/PD/740a.jpg
#   inflating: Augmented_Dataset/validation/PD/914a.jpg
#   inflating: Augmented_Dataset/validation/PD/775a.jpg
#   inflating: Augmented_Dataset/validation/PD/497a.jpg
#   inflating: Augmented_Dataset/validation/PD/981a.jpg
#   inflating: Augmented_Dataset/validation/PD/969a.jpg
#   inflating: Augmented_Dataset/validation/PD/807a.jpg
#   inflating: Augmented_Dataset/validation/PD/988a.jpg
#   inflating: Augmented_Dataset/validation/PD/730a.jpg
#   inflating: Augmented_Dataset/validation/PD/786a.jpg
#   inflating: Augmented_Dataset/validation/PD/503a.jpg
#   inflating: Augmented_Dataset/validation/PD/777a.jpg
#   inflating: Augmented_Dataset/validation/PD/536a.jpg
#   inflating: Augmented_Dataset/validation/PD/645a.jpg
#   inflating: Augmented_Dataset/validation/PD/560a.jpg
#   inflating: Augmented_Dataset/validation/PD/954a.jpg
#   inflating: Augmented_Dataset/validation/PD/710a.jpg
#   inflating: Augmented_Dataset/validation/PD/575a.jpg
#   inflating: Augmented_Dataset/validation/PD/818a.jpg
#   inflating: Augmented_Dataset/validation/PD/879a.jpg
#   inflating: Augmented_Dataset/validation/PD/473a.jpg
#   inflating: Augmented_Dataset/validation/PD/901a.jpg
#   inflating: Augmented_Dataset/validation/PD/554a.jpg
#   inflating: Augmented_Dataset/validation/PD/868a.jpg
#   inflating: Augmented_Dataset/validation/PD/685a.jpg
#   inflating: Augmented_Dataset/validation/PD/539a.jpg
#   inflating: Augmented_Dataset/validation/PD/832a.jpg
#   inflating: Augmented_Dataset/validation/PD/855a.jpg
#   inflating: Augmented_Dataset/validation/PD/567a.jpg
#   inflating: Augmented_Dataset/validation/PD/544a.jpg
#   inflating: Augmented_Dataset/validation/PD/809a.jpg
#   inflating: Augmented_Dataset/validation/PD/511a.jpg
#   inflating: Augmented_Dataset/validation/PD/598a.jpg
#   inflating: Augmented_Dataset/validation/PD/741a.jpg
#   inflating: Augmented_Dataset/validation/PD/640a.jpg
#   inflating: Augmented_Dataset/validation/PD/668a.jpg
#   inflating: Augmented_Dataset/validation/PD/490a.jpg
#   inflating: Augmented_Dataset/validation/PD/726a.jpg
#   inflating: Augmented_Dataset/validation/PD/891a.jpg
#   inflating: Augmented_Dataset/validation/PD/484a.jpg
#   inflating: Augmented_Dataset/validation/PD/523a.jpg
#   inflating: Augmented_Dataset/validation/PD/885a.jpg
#   inflating: Augmented_Dataset/validation/PD/793a.jpg
#   inflating: Augmented_Dataset/validation/PD/852a.jpg
#   inflating: Augmented_Dataset/validation/PD/594a.jpg
#   inflating: Augmented_Dataset/validation/PD/697a.jpg
#   inflating: Augmented_Dataset/validation/PD/941a.jpg
#   inflating: Augmented_Dataset/validation/PD/559a.jpg
#   inflating: Augmented_Dataset/validation/PD/700a.jpg
#   inflating: Augmented_Dataset/validation/PD/955a.jpg
#   inflating: Augmented_Dataset/validation/PD/679a.jpg
#   inflating: Augmented_Dataset/validation/PD/660a.jpg
#   inflating: Augmented_Dataset/validation/PD/893a.jpg
#   inflating: Augmented_Dataset/validation/PD/850a.jpg
#   inflating: Augmented_Dataset/validation/PD/1012a.jpg
#   inflating: Augmented_Dataset/validation/PD/985a.jpg
#   inflating: Augmented_Dataset/validation/PD/725a.jpg
#   inflating: Augmented_Dataset/validation/PD/670a.jpg
#   inflating: Augmented_Dataset/validation/PD/814a.jpg
#   inflating: Augmented_Dataset/validation/PD/502a.jpg
#   inflating: Augmented_Dataset/validation/PD/998a.jpg
#   inflating: Augmented_Dataset/validation/PD/790a.jpg
#   inflating: Augmented_Dataset/validation/PD/662a.jpg
#   inflating: Augmented_Dataset/validation/PD/920a.jpg
#   inflating: Augmented_Dataset/validation/PD/800a.jpg
#   inflating: Augmented_Dataset/validation/PD/1022a.jpg
#   inflating: Augmented_Dataset/validation/PD/919a.jpg
#   inflating: Augmented_Dataset/validation/PD/545a.jpg
#   inflating: Augmented_Dataset/validation/PD/657a.jpg
#   inflating: Augmented_Dataset/validation/PD/756a.jpg
#   inflating: Augmented_Dataset/validation/PD/791a.jpg
#   inflating: Augmented_Dataset/validation/PD/769a.jpg
#   inflating: Augmented_Dataset/validation/PD/825a.jpg
#   inflating: Augmented_Dataset/validation/PD/849a.jpg
#   inflating: Augmented_Dataset/validation/PD/959a.jpg
#   inflating: Augmented_Dataset/validation/PD/960a.jpg
#   inflating: Augmented_Dataset/validation/PD/589a.jpg
#   inflating: Augmented_Dataset/validation/PD/505a.jpg
#   inflating: Augmented_Dataset/validation/PD/857a.jpg
#   inflating: Augmented_Dataset/validation/PD/957a.jpg
#   inflating: Augmented_Dataset/validation/PD/501a.jpg
#   inflating: Augmented_Dataset/validation/PD/821a.jpg
#   inflating: Augmented_Dataset/validation/PD/841a.jpg
#   inflating: Augmented_Dataset/validation/PD/936a.jpg
#   inflating: Augmented_Dataset/validation/PD/875a.jpg
#   inflating: Augmented_Dataset/validation/PD/529a.jpg
#   inflating: Augmented_Dataset/validation/PD/532a.jpg
#   inflating: Augmented_Dataset/validation/PD/884a.jpg
#   inflating: Augmented_Dataset/validation/PD/664a.jpg
#   inflating: Augmented_Dataset/validation/PD/951a.jpg
#   inflating: Augmented_Dataset/validation/PD/842a.jpg
#   inflating: Augmented_Dataset/validation/PD/696a.jpg
#   inflating: Augmented_Dataset/validation/PD/686a.jpg
#   inflating: Augmented_Dataset/validation/PD/666a.jpg
#   inflating: Augmented_Dataset/validation/PD/1004a.jpg
#   inflating: Augmented_Dataset/validation/PD/895a.jpg
#   inflating: Augmented_Dataset/validation/PD/733a.jpg
#   inflating: Augmented_Dataset/validation/PD/921a.jpg
#   inflating: Augmented_Dataset/validation/PD/770a.jpg
#   inflating: Augmented_Dataset/validation/PD/783a.jpg
#   inflating: Augmented_Dataset/validation/PD/933a.jpg
#   inflating: Augmented_Dataset/validation/PD/583a.jpg
#   inflating: Augmented_Dataset/validation/PD/716a.jpg
#   inflating: Augmented_Dataset/validation/PD/507a.jpg
#   inflating: Augmented_Dataset/validation/PD/632a.jpg
#   inflating: Augmented_Dataset/validation/PD/847a.jpg
#   inflating: Augmented_Dataset/validation/PD/759a.jpg
#   inflating: Augmented_Dataset/validation/PD/624a.jpg
#   inflating: Augmented_Dataset/validation/PD/478a.jpg
#   inflating: Augmented_Dataset/validation/PD/720a.jpg
#   inflating: Augmented_Dataset/validation/PD/792a.jpg
#   inflating: Augmented_Dataset/validation/PD/678a.jpg
#   inflating: Augmented_Dataset/validation/PD/973a.jpg
#   inflating: Augmented_Dataset/validation/PD/646a.jpg
#   inflating: Augmented_Dataset/validation/PD/779a.jpg
#   inflating: Augmented_Dataset/validation/PD/904a.jpg
#   inflating: Augmented_Dataset/validation/PD/1019a.jpg
#   inflating: Augmented_Dataset/validation/PD/908a.jpg
#   inflating: Augmented_Dataset/validation/PD/999a.jpg
#   inflating: Augmented_Dataset/validation/PD/782a.jpg
#   inflating: Augmented_Dataset/validation/PD/550a.jpg
#   inflating: Augmented_Dataset/validation/PD/1013a.jpg
#   inflating: Augmented_Dataset/validation/PD/476a.jpg
#   inflating: Augmented_Dataset/validation/PD/979a.jpg
#   inflating: Augmented_Dataset/validation/PD/976a.jpg
#   inflating: Augmented_Dataset/validation/PD/540a.jpg
#   inflating: Augmented_Dataset/validation/PD/635a.jpg
#   inflating: Augmented_Dataset/validation/PD/975a.jpg
#   inflating: Augmented_Dataset/validation/PD/845a.jpg
#   inflating: Augmented_Dataset/validation/PD/743a.jpg
#   inflating: Augmented_Dataset/validation/PD/881a.jpg
#   inflating: Augmented_Dataset/validation/PD/924a.jpg
#   inflating: Augmented_Dataset/validation/PD/787a.jpg
#   inflating: Augmented_Dataset/validation/PD/830a.jpg
#   inflating: Augmented_Dataset/validation/PD/894a.jpg
#   inflating: Augmented_Dataset/validation/PD/1011a.jpg
#   inflating: Augmented_Dataset/validation/PD/833a.jpg
#   inflating: Augmented_Dataset/validation/PD/496a.jpg
#   inflating: Augmented_Dataset/validation/PD/585a.jpg
#   inflating: Augmented_Dataset/validation/PD/604a.jpg
#   inflating: Augmented_Dataset/validation/PD/633a.jpg
#   inflating: Augmented_Dataset/validation/PD/798a.jpg
#   inflating: Augmented_Dataset/validation/PD/974a.jpg
#   inflating: Augmented_Dataset/validation/PD/537a.jpg
#   inflating: Augmented_Dataset/validation/PD/571a.jpg
#   inflating: Augmented_Dataset/validation/PD/622a.jpg
#   inflating: Augmented_Dataset/validation/PD/940a.jpg
#   inflating: Augmented_Dataset/validation/PD/674a.jpg
#   inflating: Augmented_Dataset/validation/PD/548a.jpg
#   inflating: Augmented_Dataset/validation/PD/1009a.jpg
#   inflating: Augmented_Dataset/validation/PD/984a.jpg
#   inflating: Augmented_Dataset/validation/PD/688a.jpg
#   inflating: Augmented_Dataset/validation/PD/638a.jpg
#   inflating: Augmented_Dataset/validation/PD/639a.jpg
#   inflating: Augmented_Dataset/validation/PD/853a.jpg
#   inflating: Augmented_Dataset/validation/PD/533a.jpg
#   inflating: Augmented_Dataset/validation/PD/812a.jpg
#   inflating: Augmented_Dataset/validation/PD/929a.jpg
#   inflating: Augmented_Dataset/validation/PD/982a.jpg
#   inflating: Augmented_Dataset/validation/PD/944a.jpg
#   inflating: Augmented_Dataset/validation/PD/494a.jpg
#   inflating: Augmented_Dataset/validation/PD/848a.jpg
#   inflating: Augmented_Dataset/validation/PD/643a.jpg
#   inflating: Augmented_Dataset/validation/PD/930a.jpg
#   inflating: Augmented_Dataset/validation/PD/735a.jpg
#   inflating: Augmented_Dataset/validation/PD/993a.jpg
#   inflating: Augmented_Dataset/validation/PD/584a.jpg
#   inflating: Augmented_Dataset/validation/PD/687a.jpg
#   inflating: Augmented_Dataset/validation/PD/634a.jpg
#   inflating: Augmented_Dataset/validation/PD/572a.jpg
#   inflating: Augmented_Dataset/validation/PD/784a.jpg
#   inflating: Augmented_Dataset/validation/PD/569a.jpg
#   inflating: Augmented_Dataset/validation/PD/917a.jpg
#   inflating: Augmented_Dataset/validation/PD/488a.jpg
#   inflating: Augmented_Dataset/validation/PD/526a.jpg
#   inflating: Augmented_Dataset/validation/PD/600a.jpg
#   inflating: Augmented_Dataset/validation/PD/1003a.jpg
#   inflating: Augmented_Dataset/validation/PD/844a.jpg
#   inflating: Augmented_Dataset/validation/PD/991a.jpg
#   inflating: Augmented_Dataset/validation/PD/617a.jpg
#   inflating: Augmented_Dataset/validation/PD/602a.jpg
#   inflating: Augmented_Dataset/validation/PD/995a.jpg
#   inflating: Augmented_Dataset/validation/PD/1006a.jpg
#   inflating: Augmented_Dataset/validation/PD/672a.jpg
#   inflating: Augmented_Dataset/validation/PD/882a.jpg
#   inflating: Augmented_Dataset/validation/PD/796a.jpg
#   inflating: Augmented_Dataset/validation/PD/983a.jpg
#   inflating: Augmented_Dataset/validation/PD/898a.jpg
#   inflating: Augmented_Dataset/validation/PD/665a.jpg
#   inflating: Augmented_Dataset/validation/PD/738a.jpg
#   inflating: Augmented_Dataset/validation/PD/758a.jpg
#   inflating: Augmented_Dataset/validation/PD/573a.jpg
#   inflating: Augmented_Dataset/validation/PD/525a.jpg
#   inflating: Augmented_Dataset/validation/PD/568a.jpg
#   inflating: Augmented_Dataset/validation/PD/681a.jpg
#   inflating: Augmented_Dataset/validation/PD/595a.jpg
#   inflating: Augmented_Dataset/validation/PD/838a.jpg
#   inflating: Augmented_Dataset/validation/PD/551a.jpg
#   inflating: Augmented_Dataset/validation/PD/504a.jpg
#   inflating: Augmented_Dataset/validation/PD/781a.jpg
#   inflating: Augmented_Dataset/validation/PD/628a.jpg
#   inflating: Augmented_Dataset/validation/PD/764a.jpg
#   inflating: Augmented_Dataset/validation/PD/557a.jpg
#   inflating: Augmented_Dataset/validation/PD/889a.jpg
#   inflating: Augmented_Dataset/validation/PD/817a.jpg
#   inflating: Augmented_Dataset/validation/PD/717a.jpg
#   inflating: Augmented_Dataset/validation/PD/837a.jpg
#   inflating: Augmented_Dataset/validation/PD/542a.jpg
#   inflating: Augmented_Dataset/validation/PD/808a.jpg
#   inflating: Augmented_Dataset/validation/PD/609a.jpg
#   inflating: Augmented_Dataset/validation/PD/558a.jpg
#   inflating: Augmented_Dataset/validation/PD/937a.jpg
#   inflating: Augmented_Dataset/validation/PD/606a.jpg
#   inflating: Augmented_Dataset/validation/PD/1014a.jpg
#   inflating: Augmented_Dataset/validation/PD/506a.jpg
#   inflating: Augmented_Dataset/validation/PD/1005a.jpg
#   inflating: Augmented_Dataset/validation/PD/804a.jpg
#   inflating: Augmented_Dataset/validation/PD/859a.jpg
#   inflating: Augmented_Dataset/validation/PD/762a.jpg
#   inflating: Augmented_Dataset/validation/PD/659a.jpg
#   inflating: Augmented_Dataset/validation/PD/590a.jpg
#   inflating: Augmented_Dataset/validation/PD/970a.jpg
#   inflating: Augmented_Dataset/validation/PD/945a.jpg
#   inflating: Augmented_Dataset/validation/PD/647a.jpg
#   inflating: Augmented_Dataset/validation/PD/705a.jpg
#   inflating: Augmented_Dataset/validation/PD/862a.jpg
#   inflating: Augmented_Dataset/validation/PD/763a.jpg
#   inflating: Augmented_Dataset/validation/PD/912a.jpg
#   inflating: Augmented_Dataset/validation/PD/780a.jpg
#   inflating: Augmented_Dataset/validation/PD/722a.jpg
#   inflating: Augmented_Dataset/validation/PD/872a.jpg
#   inflating: Augmented_Dataset/validation/PD/823a.jpg
#   inflating: Augmented_Dataset/validation/PD/1008a.jpg
#   inflating: Augmented_Dataset/validation/PD/719a.jpg
#   inflating: Augmented_Dataset/validation/PD/874a.jpg

# %%
#frameRate = 1
base_dir = f'/content/Augmented_Dataset'


#train_dir = os.path.join(base_dir) #, 'train_patch'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

work_dir = "./"
color_type = 'rgb' # rgb, grayscale
BATCH_SIZE = 64
#validation_split = 0.5
img_dim = (256,256)
#list_classes = ['Monocot_Eichhornia','Monocot_Musa'] #'Monocot_Cocos',

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   #rotation_range=90,
                                   #validation_split=validation_split
                                   )
val_datagen = ImageDataGenerator(rescale=1./255,
                                #validation_split=validation_split
                                )
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=img_dim,
        batch_size=BATCH_SIZE,
        color_mode=color_type, # grayscale, rgb
        class_mode='categorical',
        interpolation='lanczos',
        #classes=list_classes,
        #subset='training'
        )
# Out:
# Found 8815 images belonging to 3 classes.

# %%
num_classes = train_generator.num_classes
total_train_data = train_generator.samples

print(f"total_train_data = {total_train_data}")
print(f"train_generator.image_shape = {train_generator.image_shape}")
print(f"num_classes = {num_classes}")
# Out:
# total_train_data = 8815
# train_generator.image_shape = (256, 256, 3)
# num_classes = 3

# %%
val_generator = val_datagen.flow_from_directory(
        val_dir,
        shuffle=False,
        target_size=img_dim,
        batch_size=BATCH_SIZE,
        color_mode=color_type, # grayscale, rgb
        class_mode='categorical',
        interpolation='lanczos',
        #classes=list_classes,
        #subset='validation'
        )
# Out:
# Found 1651 images belonging to 3 classes.

# %%
total_val_data = val_generator.samples
print(f"total_val_data = {total_val_data}")
# Out:
# total_val_data = 1651

# %%
test_generator = test_datagen.flow_from_directory(
        test_dir,
        shuffle=False,
        target_size=img_dim,
        batch_size=BATCH_SIZE,
        color_mode=color_type, # grayscale, rgb
        class_mode='categorical',
        interpolation='lanczos',
        #classes=list_classes,
        #subset='validation'
        )
# Out:
# Found 551 images belonging to 3 classes.

# %%
total_test_data = test_generator.samples
print(f"total_test_data = {total_test_data}")
# Out:
# total_test_data = 551

# %%
# DenseNet121 ResNet101 ResNet50 DenseNet201 InceptionV3 Xception NASNetLarge ResNet152V2 InceptionResNetV2 EfficientNetB7
model_name = "ResNet50"
impl_type = f"TL.3D.{model_name}" # TransferLearning3D
dataset = f"15_Class_Normal.{color_type}.{train_generator.image_shape[1]}p" # +str(img_size)+"p"
dataset
# Out:
# '15_Class_Normal.rgb.256p'

# %%
#'''
count_no_improvement = 0
epoch_initial = True
#'''

# %%
#NUM_NEURONS = 16
#NUM_LAYERS = 3
#BATCH_SIZE = 16 # 10
NUM_EPOCHS = 50
epochs_completed = 0
LEARNING_RATE = 0.0001
EPSILON = 1e-5
early_stop_after_epochs = 10
DROPOUT = 0.5 # 0.5 0.0
pad = 0

LOSS = 'categorical_crossentropy'
ACTIVATION_FUNCTION = 'relu' # relu sigmoid elu
FINAL_ACTIVATION_FUNCTION = 'softmax'
validation_split = 0.1
kernel_size=(1,1)
pointTrainableAfter = "allDefault" # "allDefault", "allFalse", 160, 170
OPTIMIZER = "Adam" # Adam SGD RMSProp
init_weights = "imagenet" # "imagenet" None
modelExt = "" #.Dense.1024.1024.2048 .Dense.128.256.512, .512.512.512 .Dense.512.512.512.512.Res
l2_val = 0.001

# +"_kernel"+str(kernel_size)+"_lr"+str(LEARNING_RATE)+"_batch"+str(BATCH_SIZE)+"_epochs"+str(NUM_EPOCHS)
#checkpointer_name  = "weights_"+dataset+"_"+impl_type+"_nLayers"+str(NUM_LAYERS)+"_nNeurons"+str(NUM_NEURONS)+".hdf5"
ext = f"" #.Flatten.l2.{str(l2_val)}.run_1 run_1 run_2 .DropAfter .momentum0.9
#'''
checkpointer_name  = "weights."+dataset+"."+impl_type+".wInit."+str(init_weights)+".TrainableAfter."+str(pointTrainableAfter)+\
                     ".lr"+str(LEARNING_RATE)+".opt."+OPTIMIZER+".batch"+str(BATCH_SIZE)+ext+".hdf5"
log_name = "log."+checkpointer_name[8:-5]+".log"

print('checkpointer_name =', checkpointer_name)
print('log_name =', log_name)
#'''
# Out:
# checkpointer_name = weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
# log_name = log.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.log

# %%
train_generator.image_shape
# Out:
# (256, 256, 3)

# %%
#'''
#base_model=DenseNet121(weights=None, include_top=False, input_shape=np_train_dataset2.shape[1:]) # `None` (random initialization)
#base_model=ResNet152V2(weights=None, include_top=False, input_shape=np_train_dataset2.shape[1:])
# ResNet152V2 ResNet50 ResNet101 ResNet152 DenseNet201 InceptionV3 Xception NASNetLarge 'imagenet' DenseNet121
#inputs = Input(final_train_imageset.shape[1:])
#x = ZeroPadding2D(padding=(pad,pad))(inputs)
#base_model=tf.keras.applications.ResNet50(weights=init_weights, include_top=False, input_tensor=x)

inputs = train_generator.image_shape
if model_name == 'ResNet50':
    base_model=tf.keras.applications.ResNet50(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'ResNet101':
    base_model=tf.keras.applications.ResNet101(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'ResNet152':
    base_model=tf.keras.applications.ResNet152(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'ResNet50V2':
    base_model=tf.keras.applications.ResNet50V2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'ResNet101V2':
    base_model=tf.keras.applications.ResNet101V2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'ResNet152V2':
    base_model=tf.keras.applications.ResNet152V2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'InceptionV3':
    base_model=tf.keras.applications.InceptionV3(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'MobileNet':
    base_model=tf.keras.applications.MobileNet(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'MobileNetV2':
    base_model=tf.keras.applications.MobileNetV2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'Xception':
    base_model=tf.keras.applications.Xception(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'NASNetMobile':
    base_model=tf.keras.applications.NASNetMobile(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'NASNetLarge':
    base_model=tf.keras.applications.NASNetLarge(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'InceptionResNetV2':
    base_model=tf.keras.applications.InceptionResNetV2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'VGG16':
    base_model=tf.keras.applications.VGG16(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'VGG19':
    base_model=tf.keras.applications.VGG19(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'DenseNet121':
    base_model=tf.keras.applications.DenseNet121(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'DenseNet169':
    base_model=tf.keras.applications.DenseNet169(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'DenseNet201':
    base_model=tf.keras.applications.DenseNet201(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB0':
    base_model=tf.keras.applications.EfficientNetB0(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB1':
    base_model=tf.keras.applications.EfficientNetB1(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB2':
    base_model=tf.keras.applications.EfficientNetB2(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB3':
    base_model=tf.keras.applications.EfficientNetB3(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB4':
    base_model=tf.keras.applications.EfficientNetB4(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB5':
    base_model=tf.keras.applications.EfficientNetB5(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB6':
    base_model=tf.keras.applications.EfficientNetB6(weights=init_weights, include_top=False, input_shape=inputs)
elif model_name == 'EfficientNetB7':
    base_model=tf.keras.applications.EfficientNetB7(weights=init_weights, include_top=False, input_shape=inputs)
    print(f"model_name = {model_name}")

x=base_model.output
#x = Activation(ACTIVATION_FUNCTION)(x)
x = Flatten()(x)
'''
x = Dense(1024,activation='elu')(x)
x = Dense(512,activation='elu')(x)
x = Dense(512,activation='elu')(x)
#'''
outputs=Dense(num_classes,activation='softmax')(x)

model=Model(inputs=base_model.input,outputs=outputs)
#model.summary()

print(f"model_name = {model_name}")
#'''
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# model_name = ResNet50

# %%
'''
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=True, show_dtype=False,
    show_layer_names=True, rankdir='TB', expand_nested=True, dpi=64
)
#'''
# Out:
# "\ntf.keras.utils.plot_model(\n    model, to_file='model.png', show_shapes=True, show_dtype=False,\n    show_layer_names=True, rankdir='TB', expand_nested=True, dpi=64\n)\n#"

# %%
#layer_names=[layer.name for layer in base_model.layers]
num_layers_base_model = len(base_model.layers)
num_layers_model = len(model.layers)

print(f"num_layers_base_model = {num_layers_base_model}")
print(f"num_layers_model = {num_layers_model}")

count_trainable = 0
count_non_trainable = 0

#'''
if pointTrainableAfter == "allDefault":
    for layer in base_model.layers:
        layer.trainable=True
        count_trainable += 1
elif pointTrainableAfter == "allFalse":
    for layer in base_model.layers:
        layer.trainable=False
        count_non_trainable += 1
elif pointTrainableAfter > 0:
    for layer in base_model.layers[:pointTrainableAfter]: # [:-pointTrainableAfter]
        layer.trainable=False
        count_non_trainable += 1
    for layer in base_model.layers[pointTrainableAfter:]: # [-pointTrainableAfter:]
        layer.trainable=True
        count_trainable += 1
#'''

'''
for layer in model.layers:
    layer.trainable=True
    count_trainable += 1
#'''

print("count_non_trainable =", count_non_trainable)
print("count_trainable =", num_layers_model-count_non_trainable)
print("Total number of layers =", num_layers_model)
# Out:
# num_layers_base_model = 175
# num_layers_model = 177
# count_non_trainable = 0
# count_trainable = 177
# Total number of layers = 177

# %%
# "RMSProp" "SGD" "Adam" "Adamax" "Adadelta" "Adagrad" "SGD"
#optimizer = tf.keras.optimizers.RMSprop(lr = LEARNING_RATE, epsilon=EPSILON)

if OPTIMIZER == "RMSProp":
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = LEARNING_RATE, epsilon=EPSILON)
elif OPTIMIZER == "Adam":
    optimizer = tf.keras.optimizers.Adam(learning_rate = LEARNING_RATE, epsilon=EPSILON, beta_1=0.9, beta_2=0.999)
elif OPTIMIZER == "Adamax":
    optimizer = tf.keras.optimizers.Adamax(learning_rate = LEARNING_RATE, epsilon=EPSILON, beta_1=0.9, beta_2=0.999)
elif OPTIMIZER == "Adadelta":
    optimizer = tf.keras.optimizers.Adadelta(learning_rate = LEARNING_RATE, epsilon=EPSILON, rho=0.95)
elif OPTIMIZER == "Adagrad":
    optimizer = tf.keras.optimizers.Adagrad(learning_rate = LEARNING_RATE, epsilon=EPSILON, initial_accumulator_value=0.1)
elif OPTIMIZER == "SGD":
    optimizer = tf.keras.optimizers.SGD(learning_rate = LEARNING_RATE, momentum=0.9)

model.compile(
    #optimizer=OPTIMIZER,
    optimizer=optimizer,
    loss=LOSS,
    metrics=['accuracy']
)

print("OPTIMIZER =", OPTIMIZER)
# Out:
# OPTIMIZER = Adam

# %%
# save the best model with least validation loss
checkpointer = ModelCheckpoint(filepath = work_dir+checkpointer_name,
                               #monitor='val_accuracy',
                               monitor='val_loss',
                               save_weights_only=False,
                               mode='auto',
                               verbose = 1, # 0 = silent, 1 = progress bar, 2 = one line per epoch
                               save_best_only =False
                               )
checkpointer_best = ModelCheckpoint(filepath = work_dir+"best_"+checkpointer_name,
                                    monitor='val_loss',
                                    save_weights_only=False,
                                    mode='auto',
                                    verbose = 1,
                                    save_best_only = True
                                    )
early_stopping = EarlyStopping(monitor='val_accuracy', patience=early_stop_after_epochs)

# %%
'''
if 'count_no_improvement' not in globals():
    count_no_improvement = 0
    print("count_no_improvement =", count_no_improvement)
#'''
'''
count_no_improvement = 0 # 0
epoch_initial = False
#'''
min_delta = 0.0009
print("count_no_improvement =", count_no_improvement)

def checkBestPerformance(epoch, logs):
    save_filepath = work_dir+"best_"+checkpointer_name

    global epoch_initial
    #print(f"epoch_initial = {epoch_initial}")
    if epoch_initial == True:
        epoch_initial = False
        model.save(filepath = save_filepath)
        print(". Model saved!")

    elif epoch_initial == False:
        global count_no_improvement

        log_data = pd.read_csv(work_dir+log_name, sep=',', usecols=['val_loss', 'val_accuracy'], engine='python')
        min_val_loss = float(str(min(log_data.val_loss.values))[:6])
        max_val_acc = float(str(max(log_data.val_accuracy.values))[:6])

        current_val_acc = float(str(logs['val_accuracy'])[:6])
        current_val_loss = float(str(logs['val_loss'])[:6])

        if (current_val_loss < min_val_loss) and (abs(current_val_loss-min_val_loss) >= min_delta):
            count_no_improvement = 0
            model.save(filepath = save_filepath)
            print("\nval_loss decreased from",min_val_loss," to",current_val_loss,"( val_accuracy =",current_val_acc,").")

        elif (current_val_loss==min_val_loss) and (current_val_acc>max_val_acc):
            count_no_improvement = 0
            model.save(filepath = save_filepath)
            print("\nval_accuracy increased to", current_val_acc, ".")

        else:
            count_no_improvement += 1
            print(". count_no_improvement =", count_no_improvement)

        if count_no_improvement >= early_stop_after_epochs-1:
            global list_callbacks
            del list_callbacks, count_no_improvement
            #print("count_no_improvement =", count_no_improvement, "... list_callbacks =", list_callbacks)
# Out:
# count_no_improvement = 0

# %%
epochs_completed = 0
list_callbacks = []
csv_logger = CSVLogger(work_dir+log_name, separator=',', append=True)

#if 'list_callbacks' in globals():
#    del list_callbacks

try:
    log_data = pd.read_csv(work_dir+log_name, sep=',', usecols=['epoch'], engine='python')
    epochs_completed = log_data.shape[0]

    #if epochs_completed > 0:
    model = load_model(work_dir+checkpointer_name)
    list_callbacks = [checkpointer, LambdaCallback(on_epoch_end=checkBestPerformance), csv_logger]
    print("epochs_completed =", epochs_completed)

except Exception as error:
    if epochs_completed == 0:
        # list_callbacks = [checkpointer, checkpointer_best, csv_logger, early_stopping]
        list_callbacks = [checkpointer, LambdaCallback(on_epoch_end=checkBestPerformance), csv_logger]
        print("epochs_completed =", epochs_completed)
    elif epochs_completed > 0:
        print(error)

print('checkpointer_name =', checkpointer_name)
# Out:
# epochs_completed = 0
# checkpointer_name = weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5

# %%
print('checkpointer_name =', checkpointer_name)
print("Previously completed epochs =", epochs_completed)
print("count_no_improvement =", count_no_improvement, "\n")

#'''
try:
    start_time = time.time()
    history = model.fit(train_generator,
                        steps_per_epoch=total_train_data // BATCH_SIZE,
                        shuffle=True,
                        epochs = NUM_EPOCHS - epochs_completed,
                        validation_data=val_generator,
                        validation_steps=total_val_data // BATCH_SIZE,
                        callbacks=list_callbacks
                        )
    elapsed_time = time.time() - start_time
    print("\nTime elapsed: ", elapsed_time)
except Exception as error:
    print("\nError:", error)
#'''
# Out:
# checkpointer_name = weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
saving model to ./weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# . count_no_improvement = 7
# 137/137 [==============================] - 135s 986ms/step - loss: 1.7096e-05 - accuracy: 1.0000 - val_loss: 0.6301 - val_accuracy: 0.8694
# Epoch 23/50
# 137/137 [==============================] - ETA: 0s - loss: 1.8353e-05 - accuracy: 1.0000
# Epoch 23: saving model to ./weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# . count_no_improvement = 8
# 137/137 [==============================] - 135s 985ms/step - loss: 1.8353e-05 - accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.8625
# Epoch 24/50
# 137/137 [==============================] - ETA: 0s - loss: 1.5482e-05 - accuracy: 1.0000
# Epoch 24: saving model to ./weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# . count_no_improvement = 9
# 137/137 [==============================] - 135s 981ms/step - loss: 1.5482e-05 - accuracy: 1.0000 - val_loss: 0.6480 - val_accuracy: 0.8669
# Epoch 25/50
# 137/137 [==============================] - ETA: 0s - loss: 1.2176e-05 - accuracy: 1.0000
# Epoch 25: saving model to ./weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Error: name 'count_no_improvement' is not defined

# %%
csv_logger = CSVLogger(work_dir+log_name, separator=',', append=True)
log_data = pd.read_csv(work_dir+log_name, sep=',', usecols=['epoch'], engine='python')
epochs_completed = log_data.shape[0]

result = model.evaluate(test_generator, steps=total_test_data // BATCH_SIZE)
print("Test Acc: {}, Test Loss: {}: ep{}, {}\n".format(round(result[1],4), round(result[0],4), epochs_completed, checkpointer_name))
# Out:
# 8/8 [==============================] - 4s 470ms/step - loss: 1.2607 - accuracy: 0.7852
# Test Acc: 0.7852, Test Loss: 1.2607: ep24, weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5

# %%
#checkpointer_name = "weights.Fashion.DenseNet121.wInit.None.TrainableAfterallDefault.opt.SGD.drop.0.0.batch32.Flatten.run_1.hdf5"
model_loaded = load_model(work_dir+"best_"+checkpointer_name)
print("Loaded "+work_dir+"best_"+checkpointer_name+".")
# Out:
# Loaded ./best_weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5.

# %%
csv_logger = CSVLogger(work_dir+log_name, separator=',', append=True)
log_data = pd.read_csv(work_dir+log_name, sep=',', usecols=['epoch'], engine='python')
epochs_completed = log_data.shape[0]
#'''

result2 = model_loaded.evaluate(test_generator, steps=total_test_data // BATCH_SIZE)
#print("nLayers: {}, nNeurons: {}, DROPOUT: {}, Test Acc: {}, Test Loss: {}".format(NUM_LAYERS, NUM_NEURONS, DROPOUT, round(result2[1], 4), round(result2[0], 4)))
print("Test Acc: {}, Test Loss: {}: ep{}, {}\n".format(round(result2[1],4), round(result2[0],4), epochs_completed, "best_"+checkpointer_name))
# Out:
# 8/8 [==============================] - 5s 462ms/step - loss: 1.1215 - accuracy: 0.7891
# Test Acc: 0.7891, Test Loss: 1.1215: ep24, best_weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5

# %%
import csv

with open(work_dir+'Records.csv', "a") as fp:
    wr = csv.writer(fp, dialect='excel')
    try:
        wr.writerow([checkpointer_name[8:-5], round(result2[1], 4), round(result2[0], 4), elapsed_time])
    except:
        wr.writerow([checkpointer_name[8:-5], round(result2[1], 4), round(result2[0], 4)])
print("Saved results.")
# Out:
# Saved results.

# %%
#Confution Matrix and Classification Report
#'''
Y_pred = model_loaded.predict_generator(test_generator, verbose=1)
#'''
#'''
save_predictions_filename = f"Y_pred.{checkpointer_name[8:-5]}"
np.save(f"{work_dir}{save_predictions_filename}", Y_pred, allow_pickle=True)
print(f"Saved: {work_dir}{save_predictions_filename}")
#'''
# Out:
# <ipython-input-31-5b75b41eb0a6>:3: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model_loaded.predict_generator(test_generator, verbose=1)
# 9/9 [==============================] - 8s 816ms/step
# Saved: ./Y_pred.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64

# %%
Y_pred_loaded = np.load(f"{work_dir}{save_predictions_filename}.npy", allow_pickle=True)
print(f"Y_pred_loaded.shape = {Y_pred_loaded.shape}")
# Out:
# Y_pred_loaded.shape = (551, 3)

# %%
y_pred = np.argmax(Y_pred_loaded, axis=1)

# %%
y_true = test_generator.classes

# %%
list_class_names_in_generator = list(test_generator.class_indices.keys())
list_class_names_in_generator[:5]
# Out:
# ['AD', 'CONTROL', 'PD']

# %%
conf_matrix = sklearn.metrics.confusion_matrix(y_true, y_pred)
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Confusion Matrix:
# [[158  26   0]
#  [ 74 101   8]
#  [  0   0 184]]

# %%
#plt.figure(figsize = (30,30))
plt.matshow(conf_matrix)

# %%
df_conf_matrix = pd.DataFrame(conf_matrix, index = [f"Class {i+1}" for i in range(num_classes)],
                  columns = [f"Class {i+1}" for i in range(num_classes)])

# %%
title = "Confusion matrix for "+dataset+" "+impl_type+"\n"
plt.figure(figsize = (10,5))
plt.title(title)
sn.heatmap(df_conf_matrix, annot=True)

img_path = work_dir+'image_conf_matrix_'+checkpointer_name[8:-5]+'.png'
plt.savefig(img_path, dpi=600)
print(f"img_path = {img_path}")
# Out:
# img_path = ./image_conf_matrix_15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.png

# %%
# Precision [TP/TP+FP] = The ratio of correctly predicted positive observations to the total predicted positive observations.
# Recall (Sensitivity) [TP/TP+FN] = The ratio of correctly predicted positive observations to the all observations in actual class - 'yes'.
# F1 score [F1 Score = 2*(Recall * Precision) / (Recall + Precision)] = The weighted average of Precision and Recall.
# Support = The number of samples of the true response that lie in that class.

print('Classification Report:')
print(sklearn.metrics.classification_report(test_generator.classes, y_pred))
#'''
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.86      0.76       184
#            1       0.80      0.55      0.65       183
#            2       0.96      1.00      0.98       184
#
#     accuracy                           0.80       551
#    macro avg       0.81      0.80      0.80       551
# weighted avg       0.81      0.80      0.80       551

# %%
val_generator.class_indices.keys()
# Out:
# dict_keys(['AD', 'CONTROL', 'PD'])

# %%
#'''
print('Classification Report')
print(sklearn.metrics.classification_report(test_generator.classes, y_pred, target_names=test_generator.class_indices.keys()))
#'''
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           AD       0.68      0.86      0.76       184
#      CONTROL       0.80      0.55      0.65       183
#           PD       0.96      1.00      0.98       184
#
#     accuracy                           0.80       551
#    macro avg       0.81      0.80      0.80       551
# weighted avg       0.81      0.80      0.80       551

# %%
log_data = pd.read_csv(work_dir+log_name, sep=',', engine='python')

# %%
# Getting the model history keys
#history.history.keys()
log_data.head()
# Out:
#    epoch  accuracy      loss  val_accuracy   val_loss
# 0      0  0.826534  0.596149      0.311875   8.836287
# 1      1  0.984116  0.044507      0.311875   5.290165
# 2      2  0.997943  0.009096      0.311875  10.218513
# 3      3  1.000000  0.001539      0.311875  15.703709
# 4      4  1.000000  0.000472      0.311875  18.633549

# %%
# plot the training artifacts
title = "Val loss for "+dataset+" "+impl_type+"\n"

plt.plot(log_data['loss'])
plt.plot(log_data['val_loss'])
#plt.title(title)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss','val_loss'], loc = 'best')
#plt.grid(b=True, which='major', axis='both')

img_path = work_dir+'image_vLoss_'+checkpointer_name[8:-5]+'.png'
plt.savefig(img_path, dpi=600)
plt.show()
print('img_path =', img_path)
# Out:
# img_path = ./image_vLoss_15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.png

# %%
title = "Val acc for "+dataset+" "+impl_type+"\n"

plt.plot(log_data['accuracy'])
plt.plot(log_data['val_accuracy'])
#plt.title(title)
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_accuracy','val_accuracy'], loc = 'best')
#plt.grid(b=True, which='major', axis='both')

img_path = work_dir+'image_vAcc_'+checkpointer_name[8:-5]+'.png'
plt.savefig(img_path, dpi=600)
plt.show()
print('img_path =', img_path)
# Out:
# img_path = ./image_vAcc_15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.png

# %%
from IPython.display import FileLink
FileLink(r'/content/best_weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5')
# Out:
# /content/best_weights.15_Class_Normal.rgb.256p.TL.3D.ResNet50.wInit.imagenet.TrainableAfter.allDefault.lr0.0001.opt.Adam.batch64.hdf5

# %%
from sklearn.metrics import accuracy_score,classification_report, roc_auc_score, matthews_corrcoef, hamming_loss, cohen_kappa_score, jaccard_score

y_actual = y_true
y_pred = y_pred

acc = classification_report(y_actual,y_pred,target_names=test_generator.class_indices.keys())
accuracy = accuracy_score(y_actual, y_pred)
mcc = matthews_corrcoef(y_actual, y_pred)
print(f"{acc}")
print(f"Accuracy Score : {accuracy}")
print(f"mcc_score : {mcc}")

hl = hamming_loss(y_actual, y_pred)
print(f"hamming_loss : {hl}")
cks = cohen_kappa_score(y_actual, y_pred)
print(f"cohen_kappa_score : {cks}")
jc = jaccard_score(y_actual, y_pred, average='weighted')
print(f"jaccard_score : {jc}")
# Out:
#               precision    recall  f1-score   support
#
#           AD       0.68      0.86      0.76       184
#      CONTROL       0.80      0.55      0.65       183
#           PD       0.96      1.00      0.98       184
#
#     accuracy                           0.80       551
#    macro avg       0.81      0.80      0.80       551
# weighted avg       0.81      0.80      0.80       551
#
# Accuracy Score : 0.8039927404718693
# mcc_score : 0.7157107386256122
# hamming_loss : 0.19600725952813067
# cohen_kappa_score : 0.7059067726248369
# jaccard_score : 0.6850288758158505

# %%
plt.plot(log_data['loss'], label="training")
plt.plot(log_data['val_loss'], label="validation")
plt.title("loss vs epochs")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.savefig('loss_vs_epochs4_latest.png',dpi=1000)

# %%
plt.plot(log_data['accuracy'], label="training")
plt.plot(log_data['val_accuracy'], label="validation")
plt.title("accuracy vs epochs")
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend()
#plt.figure(figsize=(19.20,10.80))
plt.savefig('accuracy_vs_epochs4_latest.png',dpi=1000)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

# %%
# constant for classes
classes = ('AD', 'CONTROL', 'PD')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
#plt.xticks(rotation=45)
plt.savefig('Confusion_matrix_output_float_latest.png',dpi=1000, bbox_inches='tight')

# %%
# Plot the confusion matrix using Seaborn heatmap
cf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize = (12,7))
sn.heatmap(cf_matrix, cmap="Blues", annot=True, fmt="d", xticklabels=classes, yticklabels=classes)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.savefig('Confusion_matrix_output_integer_latest.png',dpi=1000, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize = (12,7))
sn.heatmap(cf_matrix, annot=True, fmt="d", xticklabels=classes, yticklabels=classes)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.savefig('Confusion_matrix_output_integer_latest.png',dpi=1000, bbox_inches='tight')
plt.show()

# %%
def plot_training():
    '''
    This function take training model and plot history of accuracy and losses with the best epoch in both of them.
    '''

    # Define needed variables

    tr_acc = log_data['accuracy']
    tr_loss = log_data['loss']
    val_acc = log_data['val_accuracy']
    val_loss = log_data['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'

    # Plot training history
    plt.figure(figsize= (20, 8))

    #plt.subplot(1, 2, 1)
    plt.figure()
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig('loss_vs_epochs5_latest.png',dpi=1000)

    #plt.subplot(1, 2, 2)
    plt.figure()
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig('accuracy_vs_epochs5_latest.png',dpi=1000)
    plt.tight_layout
    sn.despine()

# %%
plot_training()
